# %%
# install ipykernel

# %%
import pandas as pd
from pathlib import Path

# Load datasets
BASE_DIR = Path('.')
merged_df = pd.read_csv(BASE_DIR / 'merged.tsv', sep='\t')
selected_df = pd.read_csv(BASE_DIR / 'selected.tsv', sep='\t')

print("=" * 80)
print("DATASET COMPARISON: merged.tsv vs selected.tsv")
print("=" * 80)

# Basic statistics
print("\n1. BASIC STATISTICS")
print("-" * 80)
print(f"merged.tsv rows: {len(merged_df)}")
print(f"selected.tsv rows: {len(selected_df)}")
print(f"Rows removed: {len(merged_df) - len(selected_df)} ({100 * (len(merged_df) - len(selected_df)) / len(merged_df):.2f}%)")
print(f"Rows retained: {len(selected_df)} ({100 * len(selected_df) / len(merged_df):.2f}%)")

print(f"\nmerged.tsv columns: {list(merged_df.columns)}")
print(f"selected.tsv columns: {list(selected_df.columns)}")

# Column statistics
print("\n2. COLUMN STATISTICS")
print("-" * 80)
for col in merged_df.columns:
    if col in selected_df.columns:
        print(f"\nColumn: {col}")
        print(f"  merged - dtype: {merged_df[col].dtype}, nulls: {merged_df[col].isnull().sum()}")
        print(f"  selected - dtype: {selected_df[col].dtype}, nulls: {selected_df[col].isnull().sum()}")
        
        # Numeric columns
        if pd.api.types.is_numeric_dtype(merged_df[col]):
            print(f"  merged - mean: {merged_df[col].mean():.2f}, std: {merged_df[col].std():.2f}")
            print(f"  selected - mean: {selected_df[col].mean():.2f}, std: {selected_df[col].std():.2f}")
        
        # String columns
        elif pd.api.types.is_object_dtype(merged_df[col]):
            print(f"  merged - avg length: {merged_df[col].str.len().mean():.2f}")
            print(f"  selected - avg length: {selected_df[col].str.len().mean():.2f}")

# Check for duplicates
print("\n3. DUPLICATE ANALYSIS")
print("-" * 80)
merged_dups = merged_df.duplicated().sum()
selected_dups = selected_df.duplicated().sum()
print(f"merged.tsv duplicates: {merged_dups}")
print(f"selected.tsv duplicates: {selected_dups}")

# Data quality
print("\n4. DATA QUALITY METRICS")
print("-" * 80)
print(f"merged.tsv - null values: {merged_df.isnull().sum().sum()}")
print(f"selected.tsv - null values: {selected_df.isnull().sum().sum()}")
print(f"merged.tsv - completeness: {100 * (1 - merged_df.isnull().sum().sum() / (len(merged_df) * len(merged_df.columns))):.2f}%")
print(f"selected.tsv - completeness: {100 * (1 - selected_df.isnull().sum().sum() / (len(selected_df) * len(selected_df.columns))):.2f}%")

# Intersection and difference
print("\n5. DATASET OVERLAP")
print("-" * 80)
if 'unique_id' in merged_df.columns and 'unique_id' in selected_df.columns:
    merged_ids = set(merged_df['unique_id'])
    selected_ids = set(selected_df['unique_id'])
    intersection = merged_ids & selected_ids
    
    print(f"Unique IDs in merged: {len(merged_ids)}")
    print(f"Unique IDs in selected: {len(selected_ids)}")
    print(f"Overlap: {len(intersection)}")
else:
    print("No 'unique_id' column found for overlap analysis")

# Dataset statistics
print("\n6. DATASET STATISTICS")
print("-" * 80)
dataset_col = None
for candidate in ['dataset', 'Dataset']:
    if candidate in merged_df.columns and candidate in selected_df.columns:
        dataset_col = candidate
        break

if dataset_col:
    for dataset in ['oldi', 'flores']:
        merged_count = (merged_df[dataset_col] == dataset).sum()
        selected_count = (selected_df[dataset_col] == dataset).sum()
        removed_count = merged_count - selected_count
        removed_pct = (100 * removed_count / merged_count) if merged_count else 0
        kept_pct = (100 * selected_count / merged_count) if merged_count else 0

        print(f"{dataset}:")
        print(f"  merged: {merged_count}")
        print(f"  selected: {selected_count}")
        print(f"  removed: {removed_count} ({removed_pct:.2f}%)")
        print(f"  kept: {selected_count} ({kept_pct:.2f}%)")
else:
    print("No 'dataset' column found for per-dataset analysis")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# DATASET COMPARISON: merged.tsv vs selected.tsv
# ================================================================================
#
# 1. BASIC STATISTICS
# --------------------------------------------------------------------------------
# merged.tsv rows: 8202
# selected.tsv rows: 6994
# Rows removed: 1208 (14.73%)
# Rows retained: 6994 (85.27%)
#
# merged.tsv columns: ['unique_id', 'dataset', 'original_id', 'italiano', 'veneto', 'siciliano', 'lombardo', 'sardo', 'ligure', 'friulano', 'inglese', 'spagnolo', 'francese', 'tedesco', 'catalano', 'sloveno']
# selected.tsv columns: ['unique_id', 'dataset', 'original_id', 'italiano', 'veneto', 'siciliano', 'lombardo', 'sardo', 'ligure', 'friulano', 'inglese', 'spagnolo', 'francese', 'tedesco', 'catalano', 'sloveno']
#
# 2. COLUMN STATISTICS
# --------------------------------------------------------------------------------
#
# Column: unique_id
#   merged - dtype: int64, nulls: 0
#   selected - dtype: int64, nulls: 0
#   merged - mean: 4101.50, std: 2367.86
#   selected - mean: 4270.43, std: 2327.63
#
# Column: dataset
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 4.49
#   selected - avg length: 4.52
#
# Column: original_id
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 9.22
#   selected - avg length: 9.27
#
# Column: italiano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 152.68
#   selected - avg length: 151.18
#
# Column: veneto
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 140.37
#   selected - avg length: 138.01
#
# Column: siciliano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 143.71
#   selected - avg length: 141.32
#
# Column: lombardo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 143.59
#   selected - avg length: 141.14
#
# Column: sardo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 157.29
#   selected - avg length: 155.26
#
# Column: ligure
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 150.13
#   selected - avg length: 148.01
#
# Column: friulano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 146.14
#   selected - avg length: 143.92
#
# Column: inglese
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 137.40
#   selected - avg length: 135.33
#
# Column: spagnolo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 155.21
#   selected - avg length: 153.55
#
# Column: francese
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 160.23
#   selected - avg length: 158.78
#
# Column: tedesco
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 157.21
#   selected - avg length: 155.66
#
# Column: catalano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 148.78
#   selected - avg length: 146.81
#
# Column: sloveno
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 133.36
#   selected - avg length: 130.96
#
# 3. DUPLICATE ANALYSIS
# --------------------------------------------------------------------------------
# merged.tsv duplicates: 0
# selected.tsv duplicates: 0
#
# 4. DATA QUALITY METRICS
# --------------------------------------------------------------------------------
# merged.tsv - null values: 0
# selected.tsv - null values: 0
# merged.tsv - completeness: 100.00%
# selected.tsv - completeness: 100.00%
#
# 5. DATASET OVERLAP
# --------------------------------------------------------------------------------
# Unique IDs in merged: 8202
# Unique IDs in selected: 6994
# Overlap: 6994
#
# 6. DATASET STATISTICS
# --------------------------------------------------------------------------------
# oldi:
#   merged: 6193
#   selected: 5167
#   removed: 1026 (16.57%)
#   kept: 5167 (83.43%)
# flores:
#   merged: 2009
#   selected: 1827
#   removed: 182 (9.06%)
#   kept: 1827 (90.94%)
#
# ================================================================================

# %%
# split according to dataset attribute
flores_df = selected_df[selected_df['dataset'] == 'flores']
oldi_df = selected_df[selected_df['dataset'] == 'oldi']

display(flores_df.head())
display(oldi_df.head())
# Out:
#       unique_id dataset  original_id  \
# 1538       7231  flores  flores_1038
# 1539       6404  flores   flores_211
# 1541       7544  flores  flores_1351
# 1542       7696  flores  flores_1503
# 1543       7042  flores   flores_849
#
#                                                italiano  \
# 1538  Fu derubato dai pirati, attaccato da un cane r...
# 1539  Quando è arrivato l’ufficiale, l’appartamento ...
# 1541  Per telefonare a qualcuno lontano migliaia di ...
# 1542  I bambini ferali possono aver subito gravi vio...
# 1543  Gran parte dei boomerang disponibili in Austra...
#
#                                                  veneto  \
# 1538  I pirati ło ga derubà, in Tibet xe stà atacà d...
# 1539  L’apartamento xe s-ciopà co xe rivà el funsion...
# 1541  Quando te ciama qualchedun da tanto distante t...
# 1542  I bocia selvareghi pol ver subìo gravi abusi o...
# 1543  Ła gran parte dei boomerang disponibiłi in Aus...
#
#                                               siciliano  \
# 1538  Fu sbaliciatu dî pirati, attaccàtu n’ Tibet di...
# 1539  Quannu arruvaru li funziunari, l’appartamentu ...
# 1541  Quannu chiami quarchedunu ca s’attrova a mìggh...
# 1542  Li picciriḍḍi sarbaggi ponnu aviri subbitu gra...
# 1543  La majurìa dî boomerang ca si trova 'n Austral...
#
#                                                lombardo  \
# 1538  L'è stat derubat da 'e pirati, tacat ind'ol Ti...
# 1539  Quand qe ‘l funzionari ‘l é ruvad, ‘l apartame...
# 1541  Quand qe te ciame vergun qe ‘l é miiaia de mii...
# 1542  I fiolitt selvatèg pòden vèch vivuu impurtànt ...
# 1543  La grànd pòrt di boomerang dispunìbil in Austr...
#
#                                                   sardo  \
# 1538  L’aiant rapinadu sos piratas, fiat istadu atac...
# 1539  Cando s’ufitziale est lòmpidu, s’apartamentu e...
# 1541  Cando mutis a chie si siat chi est a mìgias de...
# 1542  Sos pitzinnos agrestes diant pòdere àere àpidu...
# 1543  Sa majoria de sos boomerang a disponimentu in ...
#
#                                                  ligure  \
# 1538  O l'é stæto arröbou da di laddri de mâ, aggivo...
# 1539  Quande l'agente o l'é arrivou, o scito o l'é s...
# 1541  Quande ciammæ quarchidun ch'o l'é miggiæ de mi...
# 1542  I figgeu sarvæghi peuan avei subio di gravi ab...
# 1543  A ciù parte di boomerang disponibili in Austra...
#
#                                                friulano  \
# 1538  Al è stât vitime di robarie dai piratis, al è ...
# 1539  Cuant che l’uficiâl al è rivât, l’apartament a...
# 1541  Cuant che si clame cualchidun che al è lontan ...
# 1542  I fruts salvadis a puedin vê sperimentât pesan...
# 1543  La plui part dai boomerang disponibii in Austr...
#
#                                                 inglese  \
# 1538  He was robbed by pirates, attacked in Tibet by...
# 1539  When the official arrived, the apartment explo...
# 1541  When you call someone who is thousands of mile...
# 1542  Feral children may have experienced severe chi...
# 1543  Most boomerangs available in Australia are in ...
#
#                                                spagnolo  \
# 1538  Lo asaltaron piratas, lo mordió un perro con r...
# 1539  Cuando el empleado llegó, el departamento expl...
# 1541  Cuando uno se comunica con alguien que está a ...
# 1542  Es posible que los niños salvajes hayan sufrid...
# 1543  En verdad, la mayoría de los búmeran disponibl...
#
#                                                francese  \
# 1538  Il a été volé par des pirates, attaqué au Tibe...
# 1539  Une fois l'agent arrivé sur place, l'apparteme...
# 1541  Lorsque vous appelez une personne qui se trouv...
# 1542  Les enfants sauvages peuvent avoir subi de gra...
# 1543  En réalité, la plupart des boomerangs disponib...
#
#                                                 tedesco  \
# 1538  Er wurde von Piraten ausgeraubt, in Tibet von ...
# 1539  Als der Mitarbeiter eintraf, explodierte die W...
# 1541  Wenn Sie jemanden anrufen, der Tausende von Me...
# 1542  Wolfskinder haben möglicherweise massive Kinde...
# 1543  Die meisten Bumerangs, die in Australien erhäl...
#
#                                                catalano  \
# 1538  Va ser atracat per pirates, atacat al Tibet pe...
# 1539  L'apartament va explotar quan va arribar l'ofi...
# 1541  Quan truques a algú que es troba a milers de q...
# 1542  Els nens salvatges poden haver patit maltracta...
# 1543  La majoria dels bumerangs disponibles a Austrà...
#
#                                                 sloveno
# 1538  Oropali so ga pirati, v Tibetu ga je napadel s...
# 1539  Ko je uslužbenec prispel, je stanovanje eksplo...
# 1541  Ko pokličete nekoga, ki je oddaljen tisoče mil...
# 1542  Preden so bili zapuščeni ali so pobegnili, so ...
# 1543  Večina bumerangov, ki so na voljo v Avstraliji...
#    unique_id dataset original_id  \
# 0        554    oldi    oldi_554
# 1        865    oldi    oldi_865
# 2        384    oldi    oldi_384
# 3       1685    oldi   oldi_1685
# 4       1343    oldi   oldi_1343
#
#                                             italiano  \
# 0  Tuttavia, il contratto permetteva alla Warner ...
# 1  La geografia contribuì a creare importanti dif...
# 2  La Bacall venne per il periodo di oltre quattr...
# 3  Come riferimento a un gruppo di persone, il te...
# 4  Il Rapporto legiferava anche sugli standard mi...
#
#                                               veneto  \
# 0  Tutavia el contrato ghe dava ła posibiłità ała...
# 1  La geografia ga contribuìo a inportanti difere...
# 2  Bacall xe vegnùa pa pì de quatro mesi, assando...
# 3  Riferìo a un grupo de persone, a paroła Indige...
# 4  El Report el legislava anca sui standard minim...
#
#                                            siciliano  \
# 0  Comunqui, lu cuntrattu pirmittìa â Warners di ...
# 1  A giugrafìa cuntribbuì a criari diffirenzi giu...
# 2  Bacall ristàu pâ durata di cchiù di quattru mi...
# 3  Comu rifirimentu a nu gruppu di genti, u vocàb...
# 4  Lu Rapportu fici liggi macari supra li standar...
#
#                                             lombardo  \
# 0  Però, el cuntrat permeteva a la Warner de lass...
# 1  La greografia l’ha contribuid a tant differenz...
# 2  La Bacall l’e ndada anca lè là per i pusè de 4...
# 3  Cuma riferiment a un grupp de gent, el termin ...
# 4  El Raport g’ha regulà anca i standard minim du...
#
#                                                sardo  \
# 0  Però, su contraltu lassaiat a Warners sa possi...
# 1  Sa zeografia at determinau diferéntzias zeopol...
# 2  Bacall aiat detzisu de annare chin isse pro to...
# 3  Su fueddu indìgenu che referimentu a unu grupu...
# 4  Sa relatzione, fintzas faghiat a lege subra re...
#
#                                               ligure  \
# 0  O contratto o permetteiva a-a Warners de dâghe...
# 1  A geografia a l'à contribuio a de differense g...
# 2  A Bacall a l'é vegnua pe sto periodo de ciù de...
# 3  Comme referensa à un gruppo de persoñe, o term...
# 4  A relaçion a stabiliva de regole ascì in scî m...
#
#                                             friulano  \
# 0  Dut câs, il contrat al permeteve ae Warner di ...
# 1  La gjeografie e contribuì a impuartantis difer...
# 2  Bacall vignì tal Congo belgjic par plui di cua...
# 3  In riferiment a un grup di personis, il tiermi...
# 4  La relazion e legjiferà ancje sui standard min...
#
#                                              inglese  \
# 0  However, the contract allowed Warners to drop ...
# 1  Geography contributed to important geopolitica...
# 2  Bacall came for the over-four-month duration, ...
# 3  As a reference to a group of people, the term ...
# 4  The Report also legislated on the required, mi...
#
#                                             spagnolo  \
# 0  Sin embargo, el contrato permitía a Warners de...
# 1  La geografía contribuyó a importantes diferenc...
# 2  Bacall vino por más de cuatro meses, dejando a...
# 3  Como referencia a un grupo de personas, el tér...
# 4  El Informe también legisló sobre los estándare...
#
#                                             francese  \
# 0  Cependant, le contrat permettait à Warners de ...
# 1  La géographie a engendré des différences impor...
# 2  Bacall se rendit sur place pour une durée de p...
# 3  Le terme autochtone a été utilisé pour la prem...
# 4  Le Rapport légiféra également sur les normes m...
#
#                                              tedesco  \
# 0  Allerdings erlaubte der Vertrag Warners, ihn a...
# 1  Die Geographie trug zu wichtigen geopolitische...
# 2  Bacall kam für mehr als vier Monate und ließ i...
# 3  Als Bezug auf eine Gruppe von Menschen wurde d...
# 4  Der Bericht enthält auch Vorschriften zu den e...
#
#                                             catalano  \
# 0  No obstant això, el contracte va permetre a Wa...
# 1  La geografia va contribuir a importants diferè...
# 2  Bacall va venir durant més de quatre mesos, de...
# 3  Com a referència a un grup de persones, el ter...
# 4  L'Informe també legislava sobre els estàndards...
#
#                                              sloveno
# 0  Vendar pa je pogodba Warnerju dovoljevala, da ...
# 1  Geografija je prispevala k pomembnim geopoliti...
# 2  Bacall je prišel za več kot štiri mesece, njun...
# 3  Kot sklicevanje na skupino ljudi so izraz domo...
# 4  Poročilo je tudi uzakonilo zahtevane minimalne...

# %%
# save to csv
flores_df.to_csv(BASE_DIR / 'flores_subset.csv', index=False)
oldi_df.to_csv(BASE_DIR / 'oldi_subset.csv', index=False)
