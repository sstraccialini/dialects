# %%
# install ipykernel

# %%
import pandas as pd
from pathlib import Path

# Load datasets
BASE_DIR = Path('.')
merged_df = pd.read_csv(BASE_DIR / 'merged.tsv', sep='\t')
selected_df = pd.read_csv(BASE_DIR / 'selected.tsv', sep='\t')

print("=" * 80)
print("DATASET COMPARISON: merged.tsv vs selected.tsv")
print("=" * 80)

# Basic statistics
print("\n1. BASIC STATISTICS")
print("-" * 80)
print(f"merged.tsv rows: {len(merged_df)}")
print(f"selected.tsv rows: {len(selected_df)}")
print(f"Rows removed: {len(merged_df) - len(selected_df)} ({100 * (len(merged_df) - len(selected_df)) / len(merged_df):.2f}%)")
print(f"Rows retained: {len(selected_df)} ({100 * len(selected_df) / len(merged_df):.2f}%)")

print(f"\nmerged.tsv columns: {list(merged_df.columns)}")
print(f"selected.tsv columns: {list(selected_df.columns)}")

# Column statistics
print("\n2. COLUMN STATISTICS")
print("-" * 80)
for col in merged_df.columns:
    if col in selected_df.columns:
        print(f"\nColumn: {col}")
        print(f"  merged - dtype: {merged_df[col].dtype}, nulls: {merged_df[col].isnull().sum()}")
        print(f"  selected - dtype: {selected_df[col].dtype}, nulls: {selected_df[col].isnull().sum()}")
        
        # Numeric columns
        if pd.api.types.is_numeric_dtype(merged_df[col]):
            print(f"  merged - mean: {merged_df[col].mean():.2f}, std: {merged_df[col].std():.2f}")
            print(f"  selected - mean: {selected_df[col].mean():.2f}, std: {selected_df[col].std():.2f}")
        
        # String columns
        elif pd.api.types.is_object_dtype(merged_df[col]):
            print(f"  merged - avg length: {merged_df[col].str.len().mean():.2f}")
            print(f"  selected - avg length: {selected_df[col].str.len().mean():.2f}")

# Check for duplicates
print("\n3. DUPLICATE ANALYSIS")
print("-" * 80)
merged_dups = merged_df.duplicated().sum()
selected_dups = selected_df.duplicated().sum()
print(f"merged.tsv duplicates: {merged_dups}")
print(f"selected.tsv duplicates: {selected_dups}")

# Data quality
print("\n4. DATA QUALITY METRICS")
print("-" * 80)
print(f"merged.tsv - null values: {merged_df.isnull().sum().sum()}")
print(f"selected.tsv - null values: {selected_df.isnull().sum().sum()}")
print(f"merged.tsv - completeness: {100 * (1 - merged_df.isnull().sum().sum() / (len(merged_df) * len(merged_df.columns))):.2f}%")
print(f"selected.tsv - completeness: {100 * (1 - selected_df.isnull().sum().sum() / (len(selected_df) * len(selected_df.columns))):.2f}%")

# Intersection and difference
print("\n5. DATASET OVERLAP")
print("-" * 80)
if 'unique_id' in merged_df.columns and 'unique_id' in selected_df.columns:
    merged_ids = set(merged_df['unique_id'])
    selected_ids = set(selected_df['unique_id'])
    intersection = merged_ids & selected_ids
    
    print(f"Unique IDs in merged: {len(merged_ids)}")
    print(f"Unique IDs in selected: {len(selected_ids)}")
    print(f"Overlap: {len(intersection)}")
else:
    print("No 'unique_id' column found for overlap analysis")

# Dataset statistics
print("\n6. DATASET STATISTICS")
print("-" * 80)
dataset_col = None
for candidate in ['dataset', 'Dataset']:
    if candidate in merged_df.columns and candidate in selected_df.columns:
        dataset_col = candidate
        break

if dataset_col:
    for dataset in ['oldi', 'flores']:
        merged_count = (merged_df[dataset_col] == dataset).sum()
        selected_count = (selected_df[dataset_col] == dataset).sum()
        removed_count = merged_count - selected_count
        removed_pct = (100 * removed_count / merged_count) if merged_count else 0
        kept_pct = (100 * selected_count / merged_count) if merged_count else 0

        print(f"{dataset}:")
        print(f"  merged: {merged_count}")
        print(f"  selected: {selected_count}")
        print(f"  removed: {removed_count} ({removed_pct:.2f}%)")
        print(f"  kept: {selected_count} ({kept_pct:.2f}%)")
else:
    print("No 'dataset' column found for per-dataset analysis")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# DATASET COMPARISON: merged.tsv vs selected.tsv
# ================================================================================
#
# 1. BASIC STATISTICS
# --------------------------------------------------------------------------------
# merged.tsv rows: 8202
# selected.tsv rows: 6994
# Rows removed: 1208 (14.73%)
# Rows retained: 6994 (85.27%)
#
# merged.tsv columns: ['unique_id', 'dataset', 'original_id', 'italiano', 'veneto', 'siciliano', 'lombardo', 'sardo', 'ligure', 'friulano', 'inglese', 'spagnolo', 'francese', 'tedesco', 'catalano', 'sloveno']
# selected.tsv columns: ['unique_id', 'dataset', 'original_id', 'italiano', 'veneto', 'siciliano', 'lombardo', 'sardo', 'ligure', 'friulano', 'inglese', 'spagnolo', 'francese', 'tedesco', 'catalano', 'sloveno']
#
# 2. COLUMN STATISTICS
# --------------------------------------------------------------------------------
#
# Column: unique_id
#   merged - dtype: int64, nulls: 0
#   selected - dtype: int64, nulls: 0
#   merged - mean: 4101.50, std: 2367.86
#   selected - mean: 4270.43, std: 2327.63
#
# Column: dataset
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 4.49
#   selected - avg length: 4.52
#
# Column: original_id
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 9.22
#   selected - avg length: 9.27
#
# Column: italiano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 152.68
#   selected - avg length: 151.18
#
# Column: veneto
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 140.37
#   selected - avg length: 138.01
#
# Column: siciliano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 143.71
#   selected - avg length: 141.32
#
# Column: lombardo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 143.59
#   selected - avg length: 141.14
#
# Column: sardo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 157.29
#   selected - avg length: 155.26
#
# Column: ligure
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 150.13
#   selected - avg length: 148.01
#
# Column: friulano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 146.14
#   selected - avg length: 143.92
#
# Column: inglese
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 137.40
#   selected - avg length: 135.33
#
# Column: spagnolo
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 155.21
#   selected - avg length: 153.55
#
# Column: francese
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 160.23
#   selected - avg length: 158.78
#
# Column: tedesco
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 157.21
#   selected - avg length: 155.66
#
# Column: catalano
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 148.78
#   selected - avg length: 146.81
#
# Column: sloveno
#   merged - dtype: object, nulls: 0
#   selected - dtype: object, nulls: 0
#   merged - avg length: 133.36
#   selected - avg length: 130.96
#
# 3. DUPLICATE ANALYSIS
# --------------------------------------------------------------------------------
# merged.tsv duplicates: 0
# selected.tsv duplicates: 0
#
# 4. DATA QUALITY METRICS
# --------------------------------------------------------------------------------
# merged.tsv - null values: 0
# selected.tsv - null values: 0
# merged.tsv - completeness: 100.00%
# selected.tsv - completeness: 100.00%
#
# 5. DATASET OVERLAP
# --------------------------------------------------------------------------------
# Unique IDs in merged: 8202
# Unique IDs in selected: 6994
# Overlap: 6994
#
# 6. DATASET STATISTICS
# --------------------------------------------------------------------------------
# oldi:
#   merged: 6193
#   selected: 5167
#   removed: 1026 (16.57%)
#   kept: 5167 (83.43%)
# flores:
#   merged: 2009
#   selected: 1827
#   removed: 182 (9.06%)
#   kept: 1827 (90.94%)
#
# ================================================================================

# %%
# split according to dataset attribute
flores_df = merged_df[merged_df['dataset'] == 'flores']
oldi_df = merged_df[merged_df['dataset'] == 'oldi']

display(flores_df.head())
display(oldi_df.head())
# Out:
#       unique_id dataset original_id  \
# 6193       6194  flores    flores_1
# 6194       6195  flores    flores_2
# 6195       6196  flores    flores_3
# 6196       6197  flores    flores_4
# 6197       6198  flores    flores_5
#
#                                                italiano  \
# 6193  Nella giornata di lunedì, alcuni scienziati de...
# 6194  Secondo i responsabili della ricerca questo st...
# 6195  Il JAS 39C Gripen è precipitato su una pista d...
# 6196  L'identificazione del pilota ha rivelato che s...
# 6197  I media locali riferiscono che durante l'inter...
#
#                                                  veneto  \
# 6193  Luni i siensiati dea scuoła de medesina de l’u...
# 6194  I capi del studio dise che podarìa far trovàr ...
# 6195  El JAS 39C Gripen xe cascà su ‘na pista atorno...
# 6196  El piłota xe stà identificà come capo squadrij...
# 6197  I media locałi dise che un veicoło antincendio...
#
#                                               siciliano  \
# 6193  Luneddì, scinziati dâ Stanford University Scho...
# 6194  Li ricercaturi ncapu ô prugettu dìcunu ca chis...
# 6195  JAS 39C Gripen si fraccamàu nta na pista e 9:3...
# 6196  Lu pilota identificatu fu Dilokrit Pattavee, c...
# 6197  Li nutizzi lucali riportunu ca nu mezzu antinc...
#
#                                                lombardo  \
# 6193  Lundesdì a i sienziats de la Stanford Universi...
# 6194  A i ricercador qe a i dirijen ol projet a i g’...
# 6195  Ol JAS 39C Gripen ‘l é nait adòs a una pista i...
# 6196  Ol pillota ‘l é stait identificad coma Comanda...
# 6197  A i media locai a i hann reportad qe una camio...
#
#                                                   sardo  \
# 6193  Lunis, iscientziados dae s’ iscola de Meighina...
# 6194  Sos printzipales chircadores narant chi custu ...
# 6195  Su JAS 39C Gripen nch’est rutu subra de una pi...
# 6196  Su pilota l’ant identificadu comente su cumand...
# 6197  Sos media locales relatant de una vetura de su...
#
#                                                  ligure  \
# 6193  A-o lunesdì, i sciensiæ da Stanford University...
# 6194  I reçercatoî de ponta dixan che sto fæto chì o...
# 6195  O JAS 39C Gripen o s'é anæto à scciantâ contra...
# 6196  O pilòtto o l'é stæto identificou comme o Capp...
# 6197  I media locali repòrtan che un caro de pompê d...
#
#                                                friulano  \
# 6193  Lunis i sienziâts de Scuele di medisine de Uni...
# 6194  I ricercjadôrs principâi a disin che chest al ...
# 6195  Il Gripen JAS 39C si è sfracaiât suntune piste...
# 6196  Il pilote al è stât identificât come il cjâf d...
# 6197  I media locâi a àn riferît che un veicul antif...
#
#                                                 inglese  \
# 6193  On Monday, scientists from the Stanford Univer...
# 6194  Lead researchers say this may bring early dete...
# 6195  The JAS 39C Gripen crashed onto a runway at ar...
# 6196  The pilot was identified as Squadron Leader Di...
# 6197  Local media reports an airport fire vehicle ro...
#
#                                                spagnolo  \
# 6193  El lunes, los científicos de la facultad de me...
# 6194  Los principales investigadores principales sos...
# 6195  El JAS 39C Gripen impactó contra una pista cer...
# 6196  Se identificó al piloto como Dilokrit Pattavee...
# 6197  La prensa local informó que una patrulla de bo...
#
#                                                francese  \
# 6193  Des scientifiques de l’école de médecine de l’...
# 6194  Selon les chercheurs principaux, cela pourrait...
# 6195  Le JAS 39C Gripen s’est écrasé sur une piste a...
# 6196  Le pilote a été identifié comme étant le chef ...
# 6197  La presse locale a rapporté qu'un véhicule de ...
#
#                                                 tedesco  \
# 6193  Am Montag haben die Wisenschaftler der Stanfor...
# 6194  Führende Forscher sagen, dass dies die Früherk...
# 6195  Der JAS 39C Gripen stürzte gegen 9:30 Uhr Orts...
# 6196  Der Pilot wurde als Staffelführer Dilokrit Pat...
# 6197  Lokale Medien berichten, dass ein Feuerwehrwag...
#
#                                                catalano  \
# 6193  Dilluns, científics de la Facultat de Medicina...
# 6194  Destacats investigadors diuen que podria facil...
# 6195  El Saab 39 Gripen es va estavellar contra una ...
# 6196  Es va identificar el pilot com el líder de l'e...
# 6197  Els mitjans de comunicació locals informen que...
#
#                                                 sloveno
# 6193  Znanstveniki Medicinske fakultete Univerze v S...
# 6194  Vodilni raziskovalci pravijo, da bi to lahko p...
# 6195  JAS 39C Gripen je strmoglavilo na pristajalno ...
# 6196  Pilota so identificirali kot majorja Dilokrita...
# 6197  Lokalni mediji poročajo, da se je gasilsko voz...
#    unique_id dataset original_id  \
# 0          1    oldi      oldi_1
# 1          2    oldi      oldi_2
# 2          3    oldi      oldi_3
# 3          4    oldi      oldi_4
# 4          5    oldi      oldi_5
#
#                                             italiano  \
# 0  Lillian Diana Gish (14 ottobre 1893 – 27 febbr...
# 1  La Gish è stata un’importante star del cinema ...
# 2  Ha lavorato molto anche in televisione, dai pr...
# 3  Le prime generazioni di Gish erano ministri du...
# 4  La madre aprì il Majestic Candy Kitchen e le r...
#
#                                               veneto  \
# 0  Lillian Diana Gish (14 otobre 1893 – 27 febrar...
# 1  La Gish xe stà ‘na famosa stéa del cinema dal ...
# 2  La ga laorà tant anca in tełevision dai primi ...
# 3  Le prime generasion dei Gish gera dei ministri...
# 4  So màre gavéva vèrto el Majestic Candy Kitchen...
#
#                                            siciliano  \
# 0  Lillian Diana Gish (14 ottubbri 1893 - 27 fivr...
# 1  Gish fu na 'mpurtanti stiḍḍa dô cinema dô 1912...
# 2  Iḍḍa fici puru travagghi impurtanti nna televi...
# 3  Li primi ginirazzioni dâ famìgghia Gish furu p...
# 4  La matri aprìu la Majestic Candy Kitchen e li ...
#
#                                             lombardo  \
# 0  Lillian Diana Gish (14 de utuber del 1893 - 27...
# 1  La Gish l’era stada una atris impurtant dal 19...
# 2  Lee l’ha laürad per la televisiün dal principi...
# 3  I primm generasiün de la familia Gish l’eran p...
# 4  La sò mam l’ha dervì l’ufeleria Majestic Candy...
#
#                                                sardo  \
# 0  Lillian Diana Gish (Santu Gavinu 14, 1893 – Fr...
# 1  Gish fit una istella de su tzínema fentomada d...
# 2  Issa at fatu meda triballu in sa televisione d...
# 3  Sa primas zenerassiones de Gishes fint ministr...
# 4  Sa mama issoro abberriat sa Majestic Candy Kit...
#
#                                               ligure  \
# 0  Lillian Diana Gish (14 d’ottobre do 1893 – 27 ...
# 1  A Gish a l'é stæta unna stella do cinema da-o ...
# 2  A l'à travaggiou ben ben inta televixon da-i p...
# 3  E primme generaçioin da famiggia Gish ean past...
# 4  A seu moæ a l'aiva inandiou a Majestic Candy K...
#
#                                             friulano  \
# 0  Lillian Diana Gish (14 di Otubar 1893 - 27 di ...
# 1  Gish e fo une impuartante stele dal cine dal 1...
# 2  Jê e à lavorât une vore in television dai prin...
# 3  Lis primis gjenerazions di Gish a forin i mini...
# 4  La lôr mari e vierzè The Majestic Candy Kitche...
#
#                                              inglese  \
# 0  Lillian Diana Gish (October 14, 1893 – Februar...
# 1  Gish was a prominent film star from 1912 into ...
# 2  She also did considerable television work from...
# 3  The first several generations of Gishes were D...
# 4  Their mother opened the Majestic Candy Kitchen...
#
#                                             spagnolo  \
# 0  Lillian Diana Gish (14 de octubre de 1893 - 27...
# 1  Gish fue una estrella de cine prominente desde...
# 2  Ella también realizó un considerable trabajo e...
# 3  Las primeras generaciones de Gishes fueron los...
# 4  Su madre abrió la Majestic Candy Kitchen y las...
#
#                                             francese  \
# 0  Lillian Diana Gish (14 octobre 1893 – 27 févri...
# 1  Gish fut une star de cinéma de premier plan de...
# 2  Elle fit également un travail considérable à l...
# 3  Les premières générations de Gish furent des p...
# 4  Leur mère ouvrit le Majestic Candy Kitchen, et...
#
#                                              tedesco  \
# 0  Lillian Diana Gish (14. Oktober 1893 – 27. Feb...
# 1  Gish war von 1912 bis in die 1920er Jahre ein ...
# 2  Von den frühen 1950er bis in die 1980er Jahre ...
# 3  Die ersten Generationen von Gishes waren Minis...
# 4  Ihre Mutter eröffnete die Majestic Candy Kitch...
#
#                                             catalano  \
# 0  Lillian Diana Gish (14 d'octubre de 1893 - 27 ...
# 1  Gish va ser una estrella de cinema destacada d...
# 2  També va fer un treball considerable en televi...
# 3  Les primeres generacions de Gishes van ser min...
# 4  La seva mare va obrir la Majestic Candy Kitche...
#
#                                              sloveno
# 0  Lillian Diana Gish (14. oktober 1893 - 27. feb...
# 1  Gish je bil vidna filmska zvezda od leta 1912 ...
# 2  Opravila je tudi veliko televizijskega dela od...
# 3  Prvih nekaj generacij Gishejevih so bili Dunka...
# 4  Njuna mama je odprla Majestic Candy Kitchen, d...

# %%
# save to csv
flores_df.to_csv(BASE_DIR / 'flores_subset.csv', index=False)
oldi_df.to_csv(BASE_DIR / 'oldi_subset.csv', index=False)
